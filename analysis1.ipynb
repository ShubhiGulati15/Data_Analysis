# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
print(plt.style.available)
plt.style.use('ggplot')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %% [markdown]
# visualize the data(~%)

# %%
canada=pd.read_excel('canada (1).xlsx',sheet_name=1,skiprows=20,skipfooter=2)

# %% [markdown]
# .load and select the data(1%-10%)
# .process the data(60%-80%)
# .visualize the data(~%)

# %% [markdown]
# -Dataframe->2D matrix with rows and cols
# -series->1D matrix with 1 cols

# %% [markdown]
# ###selection of data
# -head()
# -tail()
# -sample()

# %%
canada.head(3)
# Out:
#          Type    Coverage       OdName  AREA AreaName   REG          RegName  \
# 0  Immigrants  Foreigners  Afghanistan   935     Asia  5501    Southern Asia
# 1  Immigrants  Foreigners      Albania   908   Europe   925  Southern Europe
# 2  Immigrants  Foreigners      Algeria   903   Africa   912  Northern Africa
#
#    DEV             DevName  1980  ...  2004  2005  2006  2007  2008  2009  \
# 0  902  Developing regions    16  ...  2978  3436  3009  2652  2111  1746
# 1  901   Developed regions     1  ...  1450  1223   856   702   560   716
# 2  902  Developing regions    80  ...  3616  3626  4807  3623  4005  5393
#
#    2010  2011  2012  2013
# 0  1758  2203  2635  2004
# 1   561   539   620   603
# 2  4752  4325  3774  4331
#
# [3 rows x 43 columns]

# %%
canada.sample()
# Out:
#           Type    Coverage              OdName  AREA  \
# 53  Immigrants  Foreigners  Dominican Republic   904
#
#                            AreaName  REG    RegName  DEV             DevName  \
# 53  Latin America and the Caribbean  915  Caribbean  902  Developing regions
#
#     1980  ...  2004  2005  2006  2007  2008  2009  2010  2011  2012  2013
# 53    40  ...   270   303   295   311   438   391   479   739   604   590
#
# [1 rows x 43 columns]

# %% [markdown]
# -single
#   -dict style
#   -object
# -multi column
#    -list style

# %%
canada['AreaName']
# Out:
# 0         Asia
# 1       Europe
# 2       Africa
# 3      Oceania
# 4       Europe
#         ...
# 190       Asia
# 191     Africa
# 192       Asia
# 193     Africa
# 194     Africa
# Name: AreaName, Length: 195, dtype: object

# %%
canada.OdName
# Out:
# 0         Afghanistan
# 1             Albania
# 2             Algeria
# 3      American Samoa
# 4             Andorra
#             ...
# 190          Viet Nam
# 191    Western Sahara
# 192             Yemen
# 193            Zambia
# 194          Zimbabwe
# Name: OdName, Length: 195, dtype: object

# %%
cols=['OdName',1980,1990,2000,2010]
canada[cols]
# Out:
#              OdName  1980  1990  2000  2010
# 0       Afghanistan    16  1028  3326  1758
# 1           Albania     1     3  1816   561
# 2           Algeria    80   491  2867  4752
# 3    American Samoa     0     2     0     0
# 4           Andorra     0     3     0     0
# ..              ...   ...   ...   ...   ...
# 190        Viet Nam  1191  3801  1803  1942
# 191  Western Sahara     0     0     0     0
# 192           Yemen     1     4   122   211
# 193          Zambia    11    77    39   102
# 194        Zimbabwe    72   129    98   494
#
# [195 rows x 5 columns]

# %% [markdown]
# -iloc -indexed location
# -loc -labelled location

# %%
canada.iloc[100]
# Out:
# Type               Immigrants
# Coverage           Foreigners
# OdName          Liechtenstein
# AREA                      908
# AreaName               Europe
# REG                       926
# RegName        Western Europe
# DEV                       901
# DevName     Developed regions
# 1980                        1
# 1981                        4
# 1982                        2
# 1983                        0
# 1984                        0
# 1985                        3
# 1986                        0
# 1987                        1
# 1988                        1
# 1989                        1
# 1990                        0
# 1991                        1
# 1992                        2
# 1993                        3
# 1994                        1
# 1995                        0
# 1996                        7
# 1997                        2
# 1998                        0
# 1999                        2
# 2000                        0
# 2001                        2
# ...

# %%
canada.iloc[66, 9: ].plot(kind='area')
# Out:
# <Axes: >

# %%
canada.set_index('OdName',inplace=True) # modifying index

# %%
canada
# Out:
#                       Type    Coverage  AREA AreaName   REG  \
# OdName
# Afghanistan     Immigrants  Foreigners   935     Asia  5501
# Albania         Immigrants  Foreigners   908   Europe   925
# Algeria         Immigrants  Foreigners   903   Africa   912
# American Samoa  Immigrants  Foreigners   909  Oceania   957
# Andorra         Immigrants  Foreigners   908   Europe   925
# ...                    ...         ...   ...      ...   ...
# Viet Nam        Immigrants  Foreigners   935     Asia   920
# Western Sahara  Immigrants  Foreigners   903   Africa   912
# Yemen           Immigrants  Foreigners   935     Asia   922
# Zambia          Immigrants  Foreigners   903   Africa   910
# Zimbabwe        Immigrants  Foreigners   903   Africa   910
#
#                            RegName  DEV             DevName  1980  1981  ...  \
# OdName                                                                   ...
# Afghanistan          Southern Asia  902  Developing regions    16    39  ...
# ...

# %%
Japan_data=canada.loc['Japan']

# %%
years=list(range(1980,2014))
print(years)
# Out:
# [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
canada.loc['China',years].plot(kind='area',title="China's immigration to canada",figsize=(15,5))
# Out:
# <Axes: title={'center': "China's immigration to canada"}>

# %%
countries=['china','japan']

# %%
canada.loc[countries,years].plot(kind='line',title=f'{",".join(countries)},figsize=(15,5)')
plt.savefig('comparing-3-countries.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 canada.loc[countries,years].plot(kind='line',title=f'{",".join(countries)},figsize=(15,5)')
#       2 plt.savefig('comparing-3-countries.png')
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\indexing.py:1287, in _LocIndexer._getitem_tuple(self, tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
# ...

# %% [markdown]
# sort_index helps to sort index of the dataframe if it is not sorted

# %%
canada.sort_index(ascending=False)
# Out:
#            Type    Coverage          OdName  AREA AreaName   REG  \
# 194  Immigrants  Foreigners        Zimbabwe   903   Africa   910
# 193  Immigrants  Foreigners          Zambia   903   Africa   910
# 192  Immigrants  Foreigners           Yemen   935     Asia   922
# 191  Immigrants  Foreigners  Western Sahara   903   Africa   912
# 190  Immigrants  Foreigners        Viet Nam   935     Asia   920
# ..          ...         ...             ...   ...      ...   ...
# 4    Immigrants  Foreigners         Andorra   908   Europe   925
# 3    Immigrants  Foreigners  American Samoa   909  Oceania   957
# 2    Immigrants  Foreigners         Algeria   903   Africa   912
# 1    Immigrants  Foreigners         Albania   908   Europe   925
# 0    Immigrants  Foreigners     Afghanistan   935     Asia  5501
#
#                 RegName  DEV             DevName  1980  ...  2004  2005  2006  \
# 194      Eastern Africa  902  Developing regions    72  ...  1450   615   454
# ...

# %% [markdown]
# sort_values()helps to sort value in ascending or descending order of given column

# %%
canada.sort_values(by=1980,ascending=False)
# Out:
#                                                           Type    Coverage  \
# OdName
# United Kingdom of Great Britain and Northern Ir...  Immigrants  Foreigners
# United States of America                            Immigrants  Foreigners
# India                                               Immigrants  Foreigners
# Philippines                                         Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# ...                                                        ...         ...
# Slovenia                                            Immigrants  Foreigners
# Mongolia                                            Immigrants  Foreigners
# Monaco                                              Immigrants  Foreigners
# Gambia                                              Immigrants  Foreigners
# Russian Federation                                  Immigrants  Foreigners
#
# ...

# %%
canada.sort_values(by = ['AreaName',inplace = True])
# Out:
#   Cell In[64], line 1
#     canada.sort_values(by = ['AreaName',inplace = True])
#                                         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
canada.sort_value(by=['AreaName','DevName'],ascending=[True,False])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18812\1120578555.py in ?()
# ----> 1 canada.sort_value(by=['AreaName','DevName'],ascending=[True,False])
#
# c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'sort_value'

# %%
canada['AreaName']=="Africa"
# Out:
# OdName
# Afghanistan       False
# Albania           False
# Algeria            True
# American Samoa    False
# Andorra           False
#                   ...
# Viet Nam          False
# Western Sahara     True
# Yemen             False
# Zambia             True
# Zimbabwe           True
# Name: AreaName, Length: 195, dtype: bool

# %%
canada[canada['AreaName']=="Oceania"]
# Out:
#                         Type    Coverage  AREA AreaName  REG  \
# OdName
# American Samoa    Immigrants  Foreigners   909  Oceania  957
# Australia         Immigrants  Foreigners   909  Oceania  927
# Fiji              Immigrants  Foreigners   909  Oceania  928
# Kiribati          Immigrants  Foreigners   909  Oceania  954
# Marshall Islands  Immigrants  Foreigners   909  Oceania  954
# Nauru             Immigrants  Foreigners   909  Oceania  954
# New Caledonia     Immigrants  Foreigners   909  Oceania  928
# New Zealand       Immigrants  Foreigners   909  Oceania  927
# Palau             Immigrants  Foreigners   909  Oceania  954
# Papua New Guinea  Immigrants  Foreigners   909  Oceania  928
# Samoa             Immigrants  Foreigners   909  Oceania  957
# Tonga             Immigrants  Foreigners   909  Oceania  957
# Tuvalu            Immigrants  Foreigners   909  Oceania  957
# Vanuatu           Immigrants  Foreigners   909  Oceania  928
#
# ...

# %%
canada[canada[2013]>2000]
# Out:
#                                                           Type    Coverage  \
# OdName
# Afghanistan                                         Immigrants  Foreigners
# Algeria                                             Immigrants  Foreigners
# Bangladesh                                          Immigrants  Foreigners
# Cameroon                                            Immigrants  Foreigners
# China                                               Immigrants  Foreigners
# Colombia                                            Immigrants  Foreigners
# Democratic Republic of the Congo                    Immigrants  Foreigners
# Egypt                                               Immigrants  Foreigners
# France                                              Immigrants  Foreigners
# Haiti                                               Immigrants  Foreigners
# India                                               Immigrants  Foreigners
# ...

# %% [markdown]
# Starts and maths

# %%
canada.describe(exclude=np.number)
# Out:
#               Type    Coverage AreaName       RegName             DevName
# count          195         195      195           195                 195
# unique           1           2        6            22                   2
# top     Immigrants  Foreigners   Africa  Western Asia  Developing regions
# freq           195         194       54            18                 147

# %%
canada[[1980,1990,2000,2010]].sum()
# Out:
# 1980     99137
# 1990    188054
# 2000    216712
# 2010    276956
# dtype: int64

# %%
canada[[1980,1990,2000,2010]].median()
# Out:
# 1980     13.0
# 1990     38.0
# 2000    138.0
# 2010    211.0
# dtype: float64

# %%
canada[[1980,1990,2000,2010]].sum().plot()
# Out:
# <Axes: >

# %%
canada[[1980,1990,2000,2010]].sum().plot()
# Out:
# <Axes: >

# %%
canada[[1980,1990,2000,2010]].agg(['mean','sum']).T.plot(kind='bar')
# Out:
# <Axes: >

# %%
canada['AreaName'].value_counts()
# Out:
# AreaName
# Africa                             54
# Asia                               49
# Europe                             43
# Latin America and the Caribbean    33
# Oceania                            14
# Northern America                    2
# Name: count, dtype: int64

# %%
canada['DevName'].value_counts()
# Out:
# DevName
# Developing regions    147
# Developed regions      48
# Name: count, dtype: int64

# %%
canada[years].sum(axis=1)
# Out:
# OdName
# Afghanistan       58639
# Albania           15699
# Algeria           69439
# American Samoa        6
# Andorra              15
#                   ...
# Viet Nam          97146
# Western Sahara        2
# Yemen              2985
# Zambia             1677
# Zimbabwe           8598
# Length: 195, dtype: int64

# %%
canada['total']=canada[years].sum(axis=1)

# %%
canada.head(2)
# Out:
#                    Type    Coverage  AREA AreaName   REG          RegName  \
# OdName
# Afghanistan  Immigrants  Foreigners   935     Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908   Europe   925  Southern Europe
#
#              DEV             DevName  1980  1981  ...  2005  2006  2007  2008  \
# OdName                                            ...
# Afghanistan  902  Developing regions    16    39  ...  3436  3009  2652  2111
# Albania      901   Developed regions     1     0  ...  1223   856   702   560
#
#              2009  2010  2011  2012  2013  total
# OdName
# Afghanistan  1746  1758  2203  2635  2004  58639
# Albania       716   561   539   620   603  15699
#
# [2 rows x 43 columns]

# %%
cols_to_drop=['type','coverage','Area','REG','DEV']
canada.drop(columns=cols_to_drop,inplace=True)
canada
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 2
#       1 cols_to_drop=['type','coverage','Area','REG','DEV']
# ----> 2 canada.drop(columns=cols_to_drop,inplace=True)
#       3 canada
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
# ...

# %%
canada.drop_duplicates(subset=['AreaName'])
# Out:
#                            Type    Coverage  AREA  \
# OdName
# Afghanistan          Immigrants  Foreigners   935
# Albania              Immigrants  Foreigners   908
# Algeria              Immigrants  Foreigners   903
# American Samoa       Immigrants  Foreigners   909
# Antigua and Barbuda  Immigrants  Foreigners   904
# Canada               Immigrants    Citizens   905
#
#                                             AreaName   REG           RegName  \
# OdName
# Afghanistan                                     Asia  5501     Southern Asia
# Albania                                       Europe   925   Southern Europe
# Algeria                                       Africa   912   Northern Africa
# American Samoa                               Oceania   957         Polynesia
# Antigua and Barbuda  Latin America and the Caribbean   915         Caribbean
# Canada                              Northern America   905  Northern America
#
# ...

# %%
canada.sample()
# Out:
#               Type    Coverage  AREA AreaName  REG          RegName  DEV  \
# OdName
# Sudan   Immigrants  Foreigners   903   Africa  912  Northern Africa  902
#
#                    DevName  1980  1981  ...  2004  2005  2006  2007  2008  \
# OdName                                  ...
# Sudan   Developing regions    20    12  ...  1823  1310  1039   683   622
#
#         2009  2010  2011  2012  2013
# OdName
# Sudan    422   612   531   444   343
#
# [1 rows x 42 columns]

# %%
canada.rename(mapper={
    'AreaName': 'Continent',
    'RegName': 'Region',
    'DevName': 'Status'
}, axis=1, inplace=True)

# %%
canada.head(2)
# Out:
#                    Type    Coverage  AREA Continent   REG           Region  \
# OdName
# Afghanistan  Immigrants  Foreigners   935      Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908    Europe   925  Southern Europe
#
#              DEV              Status  1980  1981  ...  2004  2005  2006  2007  \
# OdName                                            ...
# Afghanistan  902  Developing regions    16    39  ...  2978  3436  3009  2652
# Albania      901   Developed regions     1     0  ...  1450  1223   856   702
#
#              2008  2009  2010  2011  2012  2013
# OdName
# Afghanistan  2111  1746  1758  2203  2635  2004
# Albania       560   716   561   539   620   603
#
# [2 rows x 42 columns]

# %%
updated_list = ['Status', 'Continent', 'Region', 'Total']+years
print(updated_list)
# Out:
# ['Status', 'Continent', 'Region', 'Total', 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]

# %%
canada = canada[updated_list] # reordering columns
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 canada = canada[updated_list]
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
#    5880 if isinstance(key, Index):
# ...

# %%
canada.head(2)
# Out:
#                    Type    Coverage  AREA Continent   REG           Region  \
# OdName
# Afghanistan  Immigrants  Foreigners   935      Asia  5501    Southern Asia
# Albania      Immigrants  Foreigners   908    Europe   925  Southern Europe
#
#              DEV              Status  1980  1981  ...  2004  2005  2006  2007  \
# OdName                                            ...
# Afghanistan  902  Developing regions    16    39  ...  2978  3436  3009  2652
# Albania      901   Developed regions     1     0  ...  1450  1223   856   702
#
#              2008  2009  2010  2011  2012  2013
# OdName
# Afghanistan  2111  1746  1758  2203  2635  2004
# Albania       560   716   561   539   620   603
#
# [2 rows x 42 columns]

# %%
canada.groupby('Status').get_group('Developed regions')
# Out:
#                                                           Type    Coverage  \
# OdName
# Albania                                             Immigrants  Foreigners
# Andorra                                             Immigrants  Foreigners
# Australia                                           Immigrants  Foreigners
# Austria                                             Immigrants  Foreigners
# Belarus                                             Immigrants  Foreigners
# Belgium                                             Immigrants  Foreigners
# Bosnia and Herzegovina                              Immigrants  Foreigners
# Bulgaria                                            Immigrants  Foreigners
# Canada                                              Immigrants    Citizens
# Croatia                                             Immigrants  Foreigners
# Czech Republic                                      Immigrants  Foreigners
# ...

# %%
canada.groupby('Continent').get_group('Europe')
# Out:
#                                                           Type    Coverage  \
# OdName
# Albania                                             Immigrants  Foreigners
# Andorra                                             Immigrants  Foreigners
# Austria                                             Immigrants  Foreigners
# Belarus                                             Immigrants  Foreigners
# Belgium                                             Immigrants  Foreigners
# Bosnia and Herzegovina                              Immigrants  Foreigners
# Bulgaria                                            Immigrants  Foreigners
# Croatia                                             Immigrants  Foreigners
# Czech Republic                                      Immigrants  Foreigners
# Denmark                                             Immigrants  Foreigners
# Estonia                                             Immigrants  Foreigners
# ...

# %%
canada.groupby('Status')[[2000,2010]].sum()
# Out:
#                       2000    2010
# Status
# Developed regions    45469   44158
# Developing regions  171243  232798

# %%
canada.groupby('Status')[[2000,2010]].sum().plot(kind='pie', 
                                                 subplots=True, 
                                                 autopct='%1.1f%%',
                                                 figsize=(5,10),
                                                 layout=(2,1))
# Out:
# array([[<Axes: ylabel='2000'>],
#        [<Axes: ylabel='2010'>]], dtype=object)

# %%
canada.groupby('Continent')['Total'].sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 canada.groupby('Continent')['Total'].sum()
#
# NameError: name 'canada' is not defined

# %%
canada.groupby('Continent')['Total'].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 canada.groupby('Continent')['Total'].mean()
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\groupby\generic.py:1771, in DataFrameGroupBy.__getitem__(self, key)
#    1764 if isinstance(key, tuple) and len(key) > 1:
#    1765     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1766     # valid syntax, so don't raise
#    1767     raise ValueError(
#    1768         "Cannot subset columns with a tuple with more than one element. "
#    1769         "Use a list instead."
#    1770     )
# -> 1771 return super().__getitem__(key)
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\base.py:244, in SelectionMixin.__getitem__(self, key)
#     242 else:
#     243     if key not in self.obj:
# ...

# %%
canada.groupby('Continent')['Total'].agg(['mean','median'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 canada.groupby('Continent')['Total'].agg(['mean','median'])
#
# NameError: name 'canada' is not defined

# %%
canada.groupby(['Continent','Region'])['Total'].sum().reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 canada.groupby(['Continent','Region'])['Total'].sum().reset_index()
#
# NameError: name 'canada' is not defined

# %%
canada.pivot_table(columns='Status', index='Continent', 
                   values='Total', aggfunc=['min','max'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 canada.pivot_table(columns='Status', index='Continent',
#       2                    values='Total', aggfunc=['min','max'])
#
# File c:\Users\srish\.ipython\profile_default\db\lib\site-packages\pandas\core\frame.py:8579, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8562 @Substitution("")
#    8563 @Appender(_shared_docs["pivot_table"])
#    8564 def pivot_table(
#    (...)
#    8575     sort: bool = True,
#    8576 ) -> DataFrame:
#    8577     from pandas.core.reshape.pivot import pivot_table
# -> 8579     return pivot_table(
#    8580         self,
#    8581         values=values,
#    8582         index=index,
#    8583         columns=columns,
#    8584         aggfunc=aggfunc,
# ...

# %%
penguins = sns.load_dataset("penguins")
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %%
penguins_pivot.plot(kind='bar', stacked=True, figsize=(10, 5))
# Out:
# <Axes: xlabel='species'>

# %%
penguins_pivot.replace(np.nan, 0, inplace=True)

# %%
penguins_pivot.astype(int)
# Out:
# island     Biscoe  Dream  Torgersen
# species
# Adelie        188    189        191
# Chinstrap       0    195          0
# Gentoo        217      0          0
